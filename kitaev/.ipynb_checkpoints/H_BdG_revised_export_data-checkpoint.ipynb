# %%
# %pip install pfapack
# Out:
# Requirement already satisfied: pfapack in c:\users\zhuanz\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: scipy in c:\users\zhuanz\anaconda3\lib\site-packages (from pfapack) (1.13.1)
# Requirement already satisfied: numpy in c:\users\zhuanz\anaconda3\lib\site-packages (from pfapack) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
from pfapack import pfaffian
import math
import os

# %%
def create_u_matrix(N1, N2, bc1, bc2):
    N = N1 * N2 # N1 为 a_1 方向 unit cell 数量
    M = np.zeros((2 * N, 2 * N)) # M 储存 u_jk(j 属于 A 子格，k 属于 B 子格)构型
    u = np.zeros((2 * N, 2 * N))
    
    if bc1 == "PBC":
        sign1 = 1
    elif bc1 == "APBC":
        sign1 = -1
    if bc2 == "PBC":
        sign2 = 1
    elif bc2 == "APBC":
        sign2 = -1    
    
    def index(n1, n2, sub):
        return n1 + n2 * N1 + N1 * N2 * sub # A子格对应 sub=0,B子格对应 sub=1
    
    for n2 in range(N2):
        for n1 in range(N1):
            j = index(n1, n2, 0) # j 为(n1, n2)unit cell 内 A 子格格点的单指标
            
            kx = index(n1, n2, 1) # kx 为(n1, n2)unit cell 内 B 子格格点的单指标
            M[j, kx] = 1 # j 与 kx 由 x-bond 相连，一定不跨越边界
            
            ky = index((n1 + 1) % N1, n2, 1) # ky 为 (n1, n2) 往 a1 方向走一步得到的 unit cell 内 B 子格格点的单指标j 与 ky 由 y-bond 相连
            if n1 == N1 - 1:
                M[j, ky] = sign1
            else:
                M[j, ky] = 1

            kz = index(n1, (n2 + 1) % N2, 1) # kz 为 (n1, n2) 往 a2 方向走一步得到的 unit cell 内 B 子格格点的单指标，j 与 kz 由 z-bond 相连
            if n2 == N2 - 1:
                M[j, kz] = sign2
            else:
                M[j, kz] = 1
      
    u = M - M.T                        
    return u

# %%
def create_t_matrix(N1, N2, Kx, Ky, Kz, u):
    N = N1 * N2
    t = np.zeros((N, N))
    K = np.array([Kx, Ky, Kz])
    for i in range(N):
        for j in range(N):
            sum = 0
            r_i_vec = np.array([i % N1, i // N1])
            r_j_vec = np.array([j % N1, j // N1])
            
            for delta_vec in np.array([[0, 0], [1, 0], [0, 1]]):
                tmp1 = (r_j_vec[0] - delta_vec[0] + N1) % N1
                tmp2 = (r_j_vec[1] - delta_vec[1] + N2) % N2
                if (np.array_equal(r_i_vec, np.array([tmp1, tmp2]))):
                    delta_func = 1
                else:
                    delta_func = 0
                    
                tmp3 = delta_vec[0] + delta_vec[1] * 2
                K_delta = K[tmp3]

                sum += delta_func * K_delta
                
            sum *= u[i, j + N]
            t[i, j] = sum
    return t

# %%
def create_t_plus_matrix(N1, N2, u):
    N = N1 * N2
    t_plus = np.zeros((N, N))
    def index1(UC_vec, sub):
        return N1 * UC_vec[1] + UC_vec[0] + sub * N
    list1 = [np.array([1, 0]), np.array([0, 1]), np.array([0, 0])]
    list2 = [np.array([0, 1]), np.array([0, 0]), np.array([1, 0])]
    for i in range(N):
        for j in range(N):
            r_i_vec = np.array([i % N1, i // N1])
            r_j_vec = np.array([j % N1, j // N1])
            sum = 0
            
            for delta1_vec, delta2_vec in zip(list1, list2):
                tmp1 = (r_i_vec[0]-delta1_vec[0] + N1) % N1 # r_i - delta_1 的 a_1 分量，考虑了周期性边界条件
                tmp2 = (r_i_vec[1]-delta1_vec[1] + N2) % N2 # r_i - delta_1 的 a_2 分量，考虑了周期性边界条件
                tmp3 = (r_j_vec[0]-delta2_vec[0] + N1) % N1 # r_j - delta_2 的 a_1 分量，考虑了周期性边界条件
                tmp4 = (r_j_vec[1]-delta2_vec[1] + N2) % N2 # r_j - delta_2 的 a_2 分量，考虑了周期性边界条件
                if (np.array_equal(np.array([tmp1, tmp2]) , np.array([tmp3, tmp4]))):
                    delta_func = 1
                else:
                    delta_func = 0
                sum += delta_func * u[index1(r_i_vec, 1), index1(np.array([tmp1, tmp2]), 0) ] * u[index1(r_j_vec, 1), index1(np.array([tmp3, tmp4]), 0)]

            t_plus[i][j] = sum
            
    return t_plus

# %%
def create_t_minus_matrix(N1, N2, u):
    N = N1 * N2
    t_minus = np.zeros((N, N))
    def index1(UC_vec, sub):
        return N1 * UC_vec[1] + UC_vec[0] + sub * N
    list1 = [np.array([-1, 0]), np.array([0, -1]), np.array([0, 0])]
    list2 = [np.array([0, -1]), np.array([0, 0]), np.array([-1, 0])]
    for i in range(N):
        for j in range(N):
            r_i_vec = np.array([i % N1, i // N1])
            r_j_vec = np.array([j % N1, j // N1])
            sum = 0
            
            for delta1_vec, delta2_vec in zip(list1, list2):
                tmp1 = (r_i_vec[0]-delta1_vec[0] ) % N1 # r_i - delta_1 的 a_1 分量，考虑了周期性边界条件
                tmp2 = (r_i_vec[1]-delta1_vec[1] ) % N2 # r_i - delta_1 的 a_2 分量，考虑了周期性边界条件
                tmp3 = (r_j_vec[0]-delta2_vec[0] ) % N1 # r_j - delta_2 的 a_1 分量，考虑了周期性边界条件
                tmp4 = (r_j_vec[1]-delta2_vec[1] ) % N2 # r_j - delta_2 的 a_2 分量，考虑了周期性边界条件
                if (np.array_equal(np.array([tmp1, tmp2]) , np.array([tmp3, tmp4]))):
                    delta_func = 1
                else:
                    delta_func = 0
                    
                sum += delta_func * u[index1(r_i_vec, 0), index1(np.array([tmp1, tmp2]), 1) ] * u[index1(r_j_vec, 0), index1(np.array([tmp3, tmp4]), 1)]

            t_minus[i][j] = sum
            
    return t_minus

# %%
def create_P_times_P_prime_matrix(N):
    P = np.zeros((2 * N, 2* N))
    for i in range(N):
        P[i, 2 * i] = 1
        P[i + N, 2 * i + 1] = 1
    # 计算 P_prime 矩阵
    I_N = np.eye(N) # N \times N 单位矩阵
    P_prime = np.kron(I_N, 0.5 * np.array([[1, 1j], [1, -1j]]))
    #print("P_prime:\n", P_prime)
    P_times_P_prime = np.dot(P, P_prime) # 矩阵乘法
    return P_times_P_prime

# %%
def ensure_dir(path):
    os.makedirs(path, exist_ok=True)

# %%
def save_positive_eigvecs(folder, N1, N2, bc1, bc2, eigvals, eigvecs):
    N = N1 * N2
    folder = f"{type_name}_eigvecs"
    ensure_dir(folder)
    filename = f"{type_name}_eigvecs_{N1}-times-{N2}_{bc1}-{bc2}.npy"
    filepath = os.path.join(folder, filename)
    np.save(filepath, eigvecs[N:])
    print(f"[saved eigvecs] {filepath}")

# %%
def save_gs_energy(type_name, N1, N2, gs_energy_list):
    folder = f"{type_name}_GS-energy"
    ensure_dir(folder)

    filename = f"{type_name}_GS_energy_{N1}-times-{N2}.npy"
    filepath = os.path.join(folder, filename)
    np.save(filepath, np.array(gs_energy_list))
    print(f"[saved GS-energy] {filepath}"

# %%
Kx, Ky, Kz, kappa = 1, 1, 1, 0.1

# %%
start_size = 3
end_size = 100
for size in range(start_size, end_size+1):
    N1 = size
    N2 = size
    N = N1 * N2
    H_0_gs_energy_list = []
    H_total_gs_energy_list = []
    for bc1 in ["PBC", "APBC"]:
        for bc2 in ["PBC", "APBC"]:
            u = create_u_matrix(N1, N2, bc1, bc2)
            t = create_t_matrix(N1, N2, Kx, Ky, Kz, u)
            Xi = t + t.T
            Delta = -(t - t.T)
            H0 = np.block([
                [Xi, Delta],
                [-Delta, -Xi.T]
            ])
            eigvals_0, eigvecs_0 = np.linalg.eigh(H0)
            ground_state_energy_0 = np.sum(eigvals_0[:N]) / 2 # 计算无磁场时基态能量
            save_positive_eigvecs("H_0", N1, N2, bc1, bc2, eigvals_0, eigvecs_0)
            H_0_gs_energy_list.append(ground_state_energy_0)
            ############ 有磁场 ############
            # 计算磁场项哈密顿量
            t_plus = create_t_plus_matrix(N1, N2, u)
            t_minus = create_t_minus_matrix(N1, N2, u)
            Xi_prime = np.zeros((N, N), dtype = complex)
            Delta_prime = np.zeros((N, N), dtype = complex)         
            Xi_prime = 1j * kappa * (t_plus + t_minus - (t_plus + t_minus).T)
            Delta_prime = 1j * kappa * ((t_minus - t_plus) - (t_minus - t_plus).T)
    
            H_kappa = np.block([
                [Xi_prime, Delta_prime],
                [Delta_prime, Xi_prime]
            ])
            H_total = H0 + H_kappa # 总哈密顿量
            #print("H_total", H_total)
            eigvals_total, eigvecs_total = np.linalg.eigh(H_total)
            ground_state_energy_total = np.sum(eigvals_total[:N]) / 2 # 计算有磁场时体系基态能量
            save_positive_eigvecs("H_total", N1, N2, bc1, bc2, eigvals_total, eigvecs_total)
            H_total_gs_energy_list.append(ground_state_energy_0)
# Out:
# Saved: H_0\eigvals_3-times-3_PBC-PBC.txt
# Saved: H_0\eigvecs_3-times-3_PBC-PBC.txt
# Saved: H_total\eigvals_3-times-3_PBC-PBC.txt
# Saved: H_total\eigvecs_3-times-3_PBC-PBC.txt
# Saved: H_0\eigvals_3-times-3_PBC-APBC.txt
# Saved: H_0\eigvecs_3-times-3_PBC-APBC.txt
# Saved: H_total\eigvals_3-times-3_PBC-APBC.txt
# Saved: H_total\eigvecs_3-times-3_PBC-APBC.txt
# Saved: H_0\eigvals_3-times-3_APBC-PBC.txt
# Saved: H_0\eigvecs_3-times-3_APBC-PBC.txt
# Saved: H_total\eigvals_3-times-3_APBC-PBC.txt
# Saved: H_total\eigvecs_3-times-3_APBC-PBC.txt
# Saved: H_0\eigvals_3-times-3_APBC-APBC.txt
# Saved: H_0\eigvecs_3-times-3_APBC-APBC.txt
# Saved: H_total\eigvals_3-times-3_APBC-APBC.txt
# Saved: H_total\eigvecs_3-times-3_APBC-APBC.txt
# Saved: H_0\eigvals_4-times-4_PBC-PBC.txt
# Saved: H_0\eigvecs_4-times-4_PBC-PBC.txt
# Saved: H_total\eigvals_4-times-4_PBC-PBC.txt
# Saved: H_total\eigvecs_4-times-4_PBC-PBC.txt
# Saved: H_0\eigvals_4-times-4_PBC-APBC.txt
# Saved: H_0\eigvecs_4-times-4_PBC-APBC.txt
# Saved: H_total\eigvals_4-times-4_PBC-APBC.txt
# Saved: H_total\eigvecs_4-times-4_PBC-APBC.txt
# Saved: H_0\eigvals_4-times-4_APBC-PBC.txt
# Saved: H_0\eigvecs_4-times-4_APBC-PBC.txt
# Saved: H_total\eigvals_4-times-4_APBC-PBC.txt
# Saved: H_total\eigvecs_4-times-4_APBC-PBC.txt
# Saved: H_0\eigvals_4-times-4_APBC-APBC.txt
# Saved: H_0\eigvecs_4-times-4_APBC-APBC.txt
# Saved: H_total\eigvals_4-times-4_APBC-APBC.txt
# Saved: H_total\eigvecs_4-times-4_APBC-APBC.txt
# Saved: H_0\eigvals_5-times-5_PBC-PBC.txt
# Saved: H_0\eigvecs_5-times-5_PBC-PBC.txt
# Saved: H_total\eigvals_5-times-5_PBC-PBC.txt
# Saved: H_total\eigvecs_5-times-5_PBC-PBC.txt
# Saved: H_0\eigvals_5-times-5_PBC-APBC.txt
# Saved: H_0\eigvecs_5-times-5_PBC-APBC.txt
# Saved: H_total\eigvals_5-times-5_PBC-APBC.txt
# Saved: H_total\eigvecs_5-times-5_PBC-APBC.txt
# Saved: H_0\eigvals_5-times-5_APBC-PBC.txt
# Saved: H_0\eigvecs_5-times-5_APBC-PBC.txt
# Saved: H_total\eigvals_5-times-5_APBC-PBC.txt
# Saved: H_total\eigvecs_5-times-5_APBC-PBC.txt
# Saved: H_0\eigvals_5-times-5_APBC-APBC.txt
# Saved: H_0\eigvecs_5-times-5_APBC-APBC.txt
# Saved: H_total\eigvals_5-times-5_APBC-APBC.txt
# Saved: H_total\eigvecs_5-times-5_APBC-APBC.txt
# Saved: H_0\eigvals_6-times-6_PBC-PBC.txt
# Saved: H_0\eigvecs_6-times-6_PBC-PBC.txt
# Saved: H_total\eigvals_6-times-6_PBC-PBC.txt
# Saved: H_total\eigvecs_6-times-6_PBC-PBC.txt
# Saved: H_0\eigvals_6-times-6_PBC-APBC.txt
# Saved: H_0\eigvecs_6-times-6_PBC-APBC.txt
# Saved: H_total\eigvals_6-times-6_PBC-APBC.txt
# Saved: H_total\eigvecs_6-times-6_PBC-APBC.txt
# Saved: H_0\eigvals_6-times-6_APBC-PBC.txt
# Saved: H_0\eigvecs_6-times-6_APBC-PBC.txt
# Saved: H_total\eigvals_6-times-6_APBC-PBC.txt
# Saved: H_total\eigvecs_6-times-6_APBC-PBC.txt
# Saved: H_0\eigvals_6-times-6_APBC-APBC.txt
# Saved: H_0\eigvecs_6-times-6_APBC-APBC.txt
# Saved: H_total\eigvals_6-times-6_APBC-APBC.txt
# Saved: H_total\eigvecs_6-times-6_APBC-APBC.txt
# Saved: H_0\eigvals_7-times-7_PBC-PBC.txt
# Saved: H_0\eigvecs_7-times-7_PBC-PBC.txt
# Saved: H_total\eigvals_7-times-7_PBC-PBC.txt
# Saved: H_total\eigvecs_7-times-7_PBC-PBC.txt
# Saved: H_0\eigvals_7-times-7_PBC-APBC.txt
# Saved: H_0\eigvecs_7-times-7_PBC-APBC.txt
# Saved: H_total\eigvals_7-times-7_PBC-APBC.txt
# Saved: H_total\eigvecs_7-times-7_PBC-APBC.txt
# Saved: H_0\eigvals_7-times-7_APBC-PBC.txt
# Saved: H_0\eigvecs_7-times-7_APBC-PBC.txt
# Saved: H_total\eigvals_7-times-7_APBC-PBC.txt
# Saved: H_total\eigvecs_7-times-7_APBC-PBC.txt
# Saved: H_0\eigvals_7-times-7_APBC-APBC.txt
# Saved: H_0\eigvecs_7-times-7_APBC-APBC.txt
# Saved: H_total\eigvals_7-times-7_APBC-APBC.txt
# Saved: H_total\eigvecs_7-times-7_APBC-APBC.txt
# Saved: H_0\eigvals_8-times-8_PBC-PBC.txt
# Saved: H_0\eigvecs_8-times-8_PBC-PBC.txt
# Saved: H_total\eigvals_8-times-8_PBC-PBC.txt
# Saved: H_total\eigvecs_8-times-8_PBC-PBC.txt
# Saved: H_0\eigvals_8-times-8_PBC-APBC.txt
# Saved: H_0\eigvecs_8-times-8_PBC-APBC.txt
# Saved: H_total\eigvals_8-times-8_PBC-APBC.txt
# Saved: H_total\eigvecs_8-times-8_PBC-APBC.txt
# Saved: H_0\eigvals_8-times-8_APBC-PBC.txt
# Saved: H_0\eigvecs_8-times-8_APBC-PBC.txt
# Saved: H_total\eigvals_8-times-8_APBC-PBC.txt
# Saved: H_total\eigvecs_8-times-8_APBC-PBC.txt
# Saved: H_0\eigvals_8-times-8_APBC-APBC.txt
# Saved: H_0\eigvecs_8-times-8_APBC-APBC.txt
# Saved: H_total\eigvals_8-times-8_APBC-APBC.txt
# Saved: H_total\eigvecs_8-times-8_APBC-APBC.txt
# Saved: H_0\eigvals_9-times-9_PBC-PBC.txt
# Saved: H_0\eigvecs_9-times-9_PBC-PBC.txt
# Saved: H_total\eigvals_9-times-9_PBC-PBC.txt
# Saved: H_total\eigvecs_9-times-9_PBC-PBC.txt
# Saved: H_0\eigvals_9-times-9_PBC-APBC.txt
# Saved: H_0\eigvecs_9-times-9_PBC-APBC.txt
# Saved: H_total\eigvals_9-times-9_PBC-APBC.txt
# Saved: H_total\eigvecs_9-times-9_PBC-APBC.txt
# Saved: H_0\eigvals_9-times-9_APBC-PBC.txt
# Saved: H_0\eigvecs_9-times-9_APBC-PBC.txt
# Saved: H_total\eigvals_9-times-9_APBC-PBC.txt
# Saved: H_total\eigvecs_9-times-9_APBC-PBC.txt
# Saved: H_0\eigvals_9-times-9_APBC-APBC.txt
# Saved: H_0\eigvecs_9-times-9_APBC-APBC.txt
# Saved: H_total\eigvals_9-times-9_APBC-APBC.txt
# Saved: H_total\eigvecs_9-times-9_APBC-APBC.txt
# Saved: H_0\eigvals_10-times-10_PBC-PBC.txt
# Saved: H_0\eigvecs_10-times-10_PBC-PBC.txt
# Saved: H_total\eigvals_10-times-10_PBC-PBC.txt
# Saved: H_total\eigvecs_10-times-10_PBC-PBC.txt
# Saved: H_0\eigvals_10-times-10_PBC-APBC.txt
# Saved: H_0\eigvecs_10-times-10_PBC-APBC.txt
# Saved: H_total\eigvals_10-times-10_PBC-APBC.txt
# Saved: H_total\eigvecs_10-times-10_PBC-APBC.txt
# Saved: H_0\eigvals_10-times-10_APBC-PBC.txt
# Saved: H_0\eigvecs_10-times-10_APBC-PBC.txt
# Saved: H_total\eigvals_10-times-10_APBC-PBC.txt
# Saved: H_total\eigvecs_10-times-10_APBC-PBC.txt
# Saved: H_0\eigvals_10-times-10_APBC-APBC.txt
# Saved: H_0\eigvecs_10-times-10_APBC-APBC.txt
# Saved: H_total\eigvals_10-times-10_APBC-APBC.txt
# Saved: H_total\eigvecs_10-times-10_APBC-APBC.txt
# Saved: H_0\eigvals_11-times-11_PBC-PBC.txt
# Saved: H_0\eigvecs_11-times-11_PBC-PBC.txt
# Saved: H_total\eigvals_11-times-11_PBC-PBC.txt
# Saved: H_total\eigvecs_11-times-11_PBC-PBC.txt
# Saved: H_0\eigvals_11-times-11_PBC-APBC.txt
# Saved: H_0\eigvecs_11-times-11_PBC-APBC.txt
# Saved: H_total\eigvals_11-times-11_PBC-APBC.txt
# Saved: H_total\eigvecs_11-times-11_PBC-APBC.txt
# Saved: H_0\eigvals_11-times-11_APBC-PBC.txt
# Saved: H_0\eigvecs_11-times-11_APBC-PBC.txt
# Saved: H_total\eigvals_11-times-11_APBC-PBC.txt
# Saved: H_total\eigvecs_11-times-11_APBC-PBC.txt
# Saved: H_0\eigvals_11-times-11_APBC-APBC.txt
# Saved: H_0\eigvecs_11-times-11_APBC-APBC.txt
# Saved: H_total\eigvals_11-times-11_APBC-APBC.txt
# Saved: H_total\eigvecs_11-times-11_APBC-APBC.txt
# Saved: H_0\eigvals_12-times-12_PBC-PBC.txt
# Saved: H_0\eigvecs_12-times-12_PBC-PBC.txt
# Saved: H_total\eigvals_12-times-12_PBC-PBC.txt
# Saved: H_total\eigvecs_12-times-12_PBC-PBC.txt
# Saved: H_0\eigvals_12-times-12_PBC-APBC.txt
# Saved: H_0\eigvecs_12-times-12_PBC-APBC.txt
# Saved: H_total\eigvals_12-times-12_PBC-APBC.txt
# Saved: H_total\eigvecs_12-times-12_PBC-APBC.txt
# Saved: H_0\eigvals_12-times-12_APBC-PBC.txt
# Saved: H_0\eigvecs_12-times-12_APBC-PBC.txt
# Saved: H_total\eigvals_12-times-12_APBC-PBC.txt
# Saved: H_total\eigvecs_12-times-12_APBC-PBC.txt
# Saved: H_0\eigvals_12-times-12_APBC-APBC.txt
# Saved: H_0\eigvecs_12-times-12_APBC-APBC.txt
# Saved: H_total\eigvals_12-times-12_APBC-APBC.txt
# Saved: H_total\eigvecs_12-times-12_APBC-APBC.txt
# Saved: H_0\eigvals_13-times-13_PBC-PBC.txt
# Saved: H_0\eigvecs_13-times-13_PBC-PBC.txt
# Saved: H_total\eigvals_13-times-13_PBC-PBC.txt
# Saved: H_total\eigvecs_13-times-13_PBC-PBC.txt
# Saved: H_0\eigvals_13-times-13_PBC-APBC.txt
# Saved: H_0\eigvecs_13-times-13_PBC-APBC.txt
# Saved: H_total\eigvals_13-times-13_PBC-APBC.txt
# Saved: H_total\eigvecs_13-times-13_PBC-APBC.txt
# Saved: H_0\eigvals_13-times-13_APBC-PBC.txt
# Saved: H_0\eigvecs_13-times-13_APBC-PBC.txt
# Saved: H_total\eigvals_13-times-13_APBC-PBC.txt
# Saved: H_total\eigvecs_13-times-13_APBC-PBC.txt
# Saved: H_0\eigvals_13-times-13_APBC-APBC.txt
# Saved: H_0\eigvecs_13-times-13_APBC-APBC.txt
# Saved: H_total\eigvals_13-times-13_APBC-APBC.txt
# Saved: H_total\eigvecs_13-times-13_APBC-APBC.txt
# Saved: H_0\eigvals_14-times-14_PBC-PBC.txt
# Saved: H_0\eigvecs_14-times-14_PBC-PBC.txt
# Saved: H_total\eigvals_14-times-14_PBC-PBC.txt
# Saved: H_total\eigvecs_14-times-14_PBC-PBC.txt
# Saved: H_0\eigvals_14-times-14_PBC-APBC.txt
# Saved: H_0\eigvecs_14-times-14_PBC-APBC.txt
# Saved: H_total\eigvals_14-times-14_PBC-APBC.txt
# Saved: H_total\eigvecs_14-times-14_PBC-APBC.txt
# Saved: H_0\eigvals_14-times-14_APBC-PBC.txt
# Saved: H_0\eigvecs_14-times-14_APBC-PBC.txt
# Saved: H_total\eigvals_14-times-14_APBC-PBC.txt
# Saved: H_total\eigvecs_14-times-14_APBC-PBC.txt
# Saved: H_0\eigvals_14-times-14_APBC-APBC.txt
# Saved: H_0\eigvecs_14-times-14_APBC-APBC.txt
# Saved: H_total\eigvals_14-times-14_APBC-APBC.txt
# Saved: H_total\eigvecs_14-times-14_APBC-APBC.txt
# Saved: H_0\eigvals_15-times-15_PBC-PBC.txt
# Saved: H_0\eigvecs_15-times-15_PBC-PBC.txt
# Saved: H_total\eigvals_15-times-15_PBC-PBC.txt
# Saved: H_total\eigvecs_15-times-15_PBC-PBC.txt
# Saved: H_0\eigvals_15-times-15_PBC-APBC.txt
# Saved: H_0\eigvecs_15-times-15_PBC-APBC.txt
# Saved: H_total\eigvals_15-times-15_PBC-APBC.txt
# Saved: H_total\eigvecs_15-times-15_PBC-APBC.txt
# Saved: H_0\eigvals_15-times-15_APBC-PBC.txt
# Saved: H_0\eigvecs_15-times-15_APBC-PBC.txt
# Saved: H_total\eigvals_15-times-15_APBC-PBC.txt
# Saved: H_total\eigvecs_15-times-15_APBC-PBC.txt
# Saved: H_0\eigvals_15-times-15_APBC-APBC.txt
# Saved: H_0\eigvecs_15-times-15_APBC-APBC.txt
# Saved: H_total\eigvals_15-times-15_APBC-APBC.txt
# Saved: H_total\eigvecs_15-times-15_APBC-APBC.txt
# Saved: H_0\eigvals_16-times-16_PBC-PBC.txt
# Saved: H_0\eigvecs_16-times-16_PBC-PBC.txt
# Saved: H_total\eigvals_16-times-16_PBC-PBC.txt
# Saved: H_total\eigvecs_16-times-16_PBC-PBC.txt
# Saved: H_0\eigvals_16-times-16_PBC-APBC.txt
# Saved: H_0\eigvecs_16-times-16_PBC-APBC.txt
# Saved: H_total\eigvals_16-times-16_PBC-APBC.txt
# Saved: H_total\eigvecs_16-times-16_PBC-APBC.txt
# Saved: H_0\eigvals_16-times-16_APBC-PBC.txt
# Saved: H_0\eigvecs_16-times-16_APBC-PBC.txt
# Saved: H_total\eigvals_16-times-16_APBC-PBC.txt
# Saved: H_total\eigvecs_16-times-16_APBC-PBC.txt
# Saved: H_0\eigvals_16-times-16_APBC-APBC.txt
# Saved: H_0\eigvecs_16-times-16_APBC-APBC.txt
# Saved: H_total\eigvals_16-times-16_APBC-APBC.txt
# Saved: H_total\eigvecs_16-times-16_APBC-APBC.txt
# Saved: H_0\eigvals_17-times-17_PBC-PBC.txt
# Saved: H_0\eigvecs_17-times-17_PBC-PBC.txt
# Saved: H_total\eigvals_17-times-17_PBC-PBC.txt
# Saved: H_total\eigvecs_17-times-17_PBC-PBC.txt
# Saved: H_0\eigvals_17-times-17_PBC-APBC.txt
# Saved: H_0\eigvecs_17-times-17_PBC-APBC.txt
# Saved: H_total\eigvals_17-times-17_PBC-APBC.txt
# Saved: H_total\eigvecs_17-times-17_PBC-APBC.txt
# Saved: H_0\eigvals_17-times-17_APBC-PBC.txt
# Saved: H_0\eigvecs_17-times-17_APBC-PBC.txt
# Saved: H_total\eigvals_17-times-17_APBC-PBC.txt
# Saved: H_total\eigvecs_17-times-17_APBC-PBC.txt
# Saved: H_0\eigvals_17-times-17_APBC-APBC.txt
# Saved: H_0\eigvecs_17-times-17_APBC-APBC.txt
# Saved: H_total\eigvals_17-times-17_APBC-APBC.txt
# Saved: H_total\eigvecs_17-times-17_APBC-APBC.txt
# Saved: H_0\eigvals_18-times-18_PBC-PBC.txt
# Saved: H_0\eigvecs_18-times-18_PBC-PBC.txt
# Saved: H_total\eigvals_18-times-18_PBC-PBC.txt
# Saved: H_total\eigvecs_18-times-18_PBC-PBC.txt
# Saved: H_0\eigvals_18-times-18_PBC-APBC.txt
# Saved: H_0\eigvecs_18-times-18_PBC-APBC.txt
# Saved: H_total\eigvals_18-times-18_PBC-APBC.txt
# Saved: H_total\eigvecs_18-times-18_PBC-APBC.txt
# Saved: H_0\eigvals_18-times-18_APBC-PBC.txt
# Saved: H_0\eigvecs_18-times-18_APBC-PBC.txt
# Saved: H_total\eigvals_18-times-18_APBC-PBC.txt
# Saved: H_total\eigvecs_18-times-18_APBC-PBC.txt
# Saved: H_0\eigvals_18-times-18_APBC-APBC.txt
# Saved: H_0\eigvecs_18-times-18_APBC-APBC.txt
# Saved: H_total\eigvals_18-times-18_APBC-APBC.txt
# Saved: H_total\eigvecs_18-times-18_APBC-APBC.txt
# Saved: H_0\eigvals_19-times-19_PBC-PBC.txt
# Saved: H_0\eigvecs_19-times-19_PBC-PBC.txt
# Saved: H_total\eigvals_19-times-19_PBC-PBC.txt
# Saved: H_total\eigvecs_19-times-19_PBC-PBC.txt
# Saved: H_0\eigvals_19-times-19_PBC-APBC.txt
# Saved: H_0\eigvecs_19-times-19_PBC-APBC.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 23
#      20 ############ 有磁场 ############
#      21 # 计算磁场项哈密顿量
#      22 t_plus = create_t_plus_matrix(N1, N2, u)
# ---> 23 t_minus = create_t_minus_matrix(N1, N2, u)
#      24 Xi_prime = np.zeros((N, N), dtype = complex)
#      25 Delta_prime = np.zeros((N, N), dtype = complex)
#
# Cell In[31], line 19, in create_t_minus_matrix(N1, N2, u)
#      17 tmp3 = (r_j_vec[0]-delta2_vec[0] ) % N1 # r_j - delta_2 的 a_1 分量，考虑了周期性边界条件
#      18 tmp4 = (r_j_vec[1]-delta2_vec[1] ) % N2 # r_j - delta_2 的 a_2 分量，考虑了周期性边界条件
# ---> 19 if (np.array_equal(np.array([tmp1, tmp2]) , np.array([tmp3, tmp4]))):
#      20     delta_func = 1
#      21 else:
#
# File ~\anaconda3\Lib\site-packages\numpy\core\numeric.py:2439, in array_equal(a1, a2, equal_nan)
#    2437     return False
#    2438 if not equal_nan:
# -> 2439     return bool(asarray(a1 == a2).all())
#    2440 # Handling NaN values if equal_nan is True
#    2441 a1nan, a2nan = isnan(a1), isnan(a2)
#
# File ~\anaconda3\Lib\site-packages\numpy\core\_methods.py:64, in _all(a, axis, dtype, out, keepdims, where)
#      61 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      62     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63     if where is True:
# ---> 64         return umr_all(a, axis, dtype, out, keepdims)
#      65     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:
